# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent
sys.path.insert(0, str(ROOT))

print("Project root added:", ROOT)
# Out:
# Project root added: c:\Users\Aditya Pratap Singh\OneDrive\Desktop\Codes2\mimir-v0

# %%
from configs.config_loader import load_configs
from core.model_loader import load_model_and_tokenizer
from core.incident_loader import get_incident_ids, load_incident
from core.prompt_builder import prompt_builder
from core.generator import chat_builder, generate_response

# %%
base_cfg = load_configs("base_configs")
model_cfg = load_configs("model_configs")

# %%
model, tokenizer = load_model_and_tokenizer(
    model_name = model_cfg["model"]["name"],
    torch_dtype = model_cfg["model"]["torch_dtype"],
    device_map = model_cfg["model"]["device_map"])
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File c:\miniconda3\envs\mimirv0\lib\site-packages\huggingface_hub\utils\_http.py:720, in hf_raise_for_status(response, endpoint_name)
#     719 try:
# --> 720     response.raise_for_status()
#     721 except httpx.HTTPStatusError as e:
#
# File c:\miniconda3\envs\mimirv0\lib\site-packages\httpx\_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '403 Forbidden' for url 'https://huggingface.co/Qwen/Qwen2.5-3B-Instruct/resolve/main/config.json'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/403
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# File c:\miniconda3\envs\mimirv0\lib\site-packages\huggingface_hub\file_download.py:1649, in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder, retry_on_errors)
#    1648 try:
# -> 1649     metadata = get_hf_file_metadata(
#    1650         url=url,
#    1651         timeout=etag_timeout,
#    1652         headers=headers,
#    1653         token=token,
#    1654         endpoint=endpoint,
#    1655         retry_on_errors=retry_on_errors,
#    1656     )
#    1657 except RemoteEntryNotFoundError as http_error:
#
# File c:\miniconda3\envs\mimirv0\lib\site-packages\huggingface_hub\utils\_validators.py:89, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      87 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 89 return fn(*args, **kwargs)
#
# File c:\miniconda3\envs\mimirv0\lib\site-packages\huggingface_hub\file_download.py:1572, in get_hf_file_metadata(url, token, timeout, library_name, library_version, user_agent, headers, endpoint, retry_on_errors)
#    1571 # Retrieve metadata
# -> 1572 response = _httpx_follow_relative_redirects_with_backoff(
#    1573     method="HEAD", url=url, headers=hf_headers, timeout=timeout, retry_on_errors=retry_on_errors
#    1574 )
#    1575 hf_raise_for_status(response)
#
# File c:\miniconda3\envs\mimirv0\lib\site-packages\huggingface_hub\utils\_http.py:651, in _httpx_follow_relative_redirects_with_backoff(method, url, retry_on_errors, **httpx_kwargs)
#     644 response = http_backoff(
#     645     method=method,
#     646     url=url,
#    (...)
#     649     **no_retry_kwargs,
#     650 )
# --> 651 hf_raise_for_status(response)
#     653 # Check if response is a relative redirect
#
# File c:\miniconda3\envs\mimirv0\lib\site-packages\huggingface_hub\utils\_http.py:802, in hf_raise_for_status(response, endpoint_name)
#     797     message = (
#     798         f"\n\n{response.status_code} Forbidden: {error_message}."
#     799         + f"\nCannot access content at: {response.url}."
#     800         + "\nMake sure your token has the correct permissions."
#     801     )
# --> 802     raise _format(HfHubHTTPError, message, response) from e
#     804 elif response.status_code == 429:
#
# HfHubHTTPError: (Amz CF ID: 5g9PIPfl737IZxRiy92hbIoLMJOyCSvWnAHBpvIW9gGKsdyM9Nqrww==)
#
# 403 Forbidden: None.
# Cannot access content at: https://huggingface.co/Qwen/Qwen2.5-3B-Instruct/resolve/main/config.json.
# Make sure your token has the correct permissions.
#
# The above exception was the direct cause of the following exception:
#
# LocalEntryNotFoundError                   Traceback (most recent call last)
# File c:\miniconda3\envs\mimirv0\lib\site-packages\transformers\utils\hub.py:419, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     417 if len(full_filenames) == 1:
#     418     # This is slightly better for only 1 file
# --> 419     hf_hub_download(
#     420         path_or_repo_id,
#     421         filenames[0],
#     422         subfolder=None if len(subfolder) == 0 else subfolder,
#     423         repo_type=repo_type,
#     424         revision=revision,
#     425         cache_dir=cache_dir,
#     426         user_agent=user_agent,
#     427         force_download=force_download,
#     428         proxies=proxies,
#     429         token=token,
#     430         local_files_only=local_files_only,
#     431     )
#     432 else:
#
# File c:\miniconda3\envs\mimirv0\lib\site-packages\huggingface_hub\utils\_validators.py:89, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      87 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 89 return fn(*args, **kwargs)
#
# File c:\miniconda3\envs\mimirv0\lib\site-packages\huggingface_hub\file_download.py:982, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, etag_timeout, token, local_files_only, headers, endpoint, tqdm_class, dry_run)
#     981 else:
# --> 982     return _hf_hub_download_to_cache_dir(
#     983         # Destination
#     984         cache_dir=cache_dir,
#     985         # File info
#     986         repo_id=repo_id,
#     987         filename=filename,
#     988         repo_type=repo_type,
#     989         revision=revision,
#     990         # HTTP info
#     991         endpoint=endpoint,
#     992         etag_timeout=etag_timeout,
#     993         headers=hf_headers,
#     994         token=token,
#     995         # Additional options
#     996         local_files_only=local_files_only,
#     997         force_download=force_download,
#     998         tqdm_class=tqdm_class,
#     999         dry_run=dry_run,
#    1000     )
#
# File c:\miniconda3\envs\mimirv0\lib\site-packages\huggingface_hub\file_download.py:1133, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, force_download, tqdm_class, dry_run)
#    1132     if head_call_error is not None:
# -> 1133         _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1135 # From now on, etag, commit_hash, url and size are not None.
#
# File c:\miniconda3\envs\mimirv0\lib\site-packages\huggingface_hub\file_download.py:1765, in _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1763 else:
#    1764     # Otherwise: most likely a connection issue or Hub downtime => let's warn the user
# -> 1765     raise LocalEntryNotFoundError(
#    1766         "An error happened while trying to locate the file on the Hub and we cannot find the requested files"
#    1767         " in the local cache. Please check your connection and try again or make sure your Internet connection"
#    1768         " is on."
#    1769     ) from head_call_error
#
# LocalEntryNotFoundError: An error happened while trying to locate the file on the Hub and we cannot find the requested files in the local cache. Please check your connection and try again or make sure your Internet connection is on.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 model, tokenizer = load_model_and_tokenizer(
#       2     model_name = model_cfg["model"]["name"],
#       3     torch_dtype = model_cfg["model"]["torch_dtype"],
#       4     device_map = model_cfg["model"]["device_map"])
#
# File c:\Users\Aditya Pratap Singh\OneDrive\Desktop\Codes2\mimir-v0\core\model_loader.py:8, in load_model_and_tokenizer(model_name, torch_dtype, device_map)
#       5 def load_model_and_tokenizer(model_name : str, torch_dtype : str,
#       6                              device_map: str)-> Any:
# ----> 8     model = AutoModelForCausalLM.from_pretrained(
#       9         model_name,
#      10         torch_dtype = torch_dtype,
#      11         device_map = device_map
#      12     )
#      14     tokenizer = AutoTokenizer.from_pretrained(model_name)
#      16     return [model, tokenizer]
#
# File c:\miniconda3\envs\mimirv0\lib\site-packages\transformers\models\auto\auto_factory.py:319, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     316 if kwargs.get("quantization_config") is not None:
#     317     _ = kwargs.pop("quantization_config")
# --> 319 config, kwargs = AutoConfig.from_pretrained(
#     320     pretrained_model_name_or_path,
#     321     return_unused_kwargs=True,
#     322     code_revision=code_revision,
#     323     _commit_hash=commit_hash,
#     324     **hub_kwargs,
#     325     **kwargs,
#     326 )
#     328 # if torch_dtype=auto was passed here, ensure to pass it on
#     329 if kwargs_orig.get("torch_dtype", None) == "auto":
#
# File c:\miniconda3\envs\mimirv0\lib\site-packages\transformers\models\auto\configuration_auto.py:1403, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1400 trust_remote_code = kwargs.pop("trust_remote_code", None)
#    1401 code_revision = kwargs.pop("code_revision", None)
# -> 1403 config_dict, unused_kwargs = PreTrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#    1404 has_remote_code = "auto_map" in config_dict and "AutoConfig" in config_dict["auto_map"]
#    1405 has_local_code = "model_type" in config_dict and config_dict["model_type"] in CONFIG_MAPPING
#
# File c:\miniconda3\envs\mimirv0\lib\site-packages\transformers\configuration_utils.py:572, in PreTrainedConfig.get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     570 original_kwargs = copy.deepcopy(kwargs)
#     571 # Get config dict associated with the base config file
# --> 572 config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     573 if config_dict is None:
#     574     return {}, kwargs
#
# File c:\miniconda3\envs\mimirv0\lib\site-packages\transformers\configuration_utils.py:627, in PreTrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     623 configuration_file = kwargs.pop("_configuration_file", CONFIG_NAME) if gguf_file is None else gguf_file
#     625 try:
#     626     # Load from local folder or from cache or download from model Hub and cache
# --> 627     resolved_config_file = cached_file(
#     628         pretrained_model_name_or_path,
#     629         configuration_file,
#     630         cache_dir=cache_dir,
#     631         force_download=force_download,
#     632         proxies=proxies,
#     633         local_files_only=local_files_only,
#     634         token=token,
#     635         user_agent=user_agent,
#     636         revision=revision,
#     637         subfolder=subfolder,
#     638         _commit_hash=commit_hash,
#     639     )
#     640     if resolved_config_file is None:
#     641         return None, kwargs
#
# File c:\miniconda3\envs\mimirv0\lib\site-packages\transformers\utils\hub.py:276, in cached_file(path_or_repo_id, filename, **kwargs)
#     221 def cached_file(
#     222     path_or_repo_id: str | os.PathLike,
#     223     filename: str,
#     224     **kwargs,
#     225 ) -> str | None:
#     226     """
#     227     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     228
#    (...)
#     274     ```
#     275     """
# --> 276     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     277     file = file[0] if file is not None else file
#     278     return file
#
# File c:\miniconda3\envs\mimirv0\lib\site-packages\transformers\utils\hub.py:493, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     490     # Here we only raise if both flags for missing entry and connection errors are True (because it can be raised
#     491     # even when `local_files_only` is True, in which case raising for connections errors only would not make sense)
#     492     elif _raise_exceptions_for_missing_entries:
# --> 493         raise OSError(
#     494             f"We couldn't connect to '{constants.ENDPOINT}' to load the files, and couldn't find them in the"
#     495             f" cached files.\nCheck your internet connection or see how to run the library in offline mode at"
#     496             " 'https://huggingface.co/docs/transformers/installation#offline-mode'."
#     497         ) from e
#     498 # snapshot_download will not raise EntryNotFoundError, but hf_hub_download can. If this is the case, it will be treated
#     499 # later on anyway and re-raised if needed
#     500 elif isinstance(e, HfHubHTTPError) and not isinstance(e, EntryNotFoundError):
#
# OSError: We couldn't connect to 'https://huggingface.co' to load the files, and couldn't find them in the cached files.
# Check your internet connection or see how to run the library in offline mode at 'https://huggingface.co/docs/transformers/installation#offline-mode'.
